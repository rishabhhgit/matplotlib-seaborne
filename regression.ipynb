# %% [markdown]
# <a href="https://colab.research.google.com/github/rishabhhgit/matplotlib-seaborne/blob/main/regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # lmplot()
# *regression plot is used in machine learning so we will not fully discuss what, how and where it is used
# but we will see how it is created and what are the values we can put inside it*

# %%
tips = sns.load_dataset("tips")

# %%
sns.lmplot(x = 'total_bill',y = 'tip',data = tips)

# %%
sns.lmplot(x = 'total_bill',y = 'tip',data = tips,hue = 'sex')

# %%
sns.lmplot(x = 'total_bill',y = 'tip',data = tips,hue = 'sex',palette='coolwarm')

# %%
sns.lmplot(x = 'total_bill',y = 'tip',data = tips,hue = 'sex',palette='coolwarm',markers=['o','v'], scatter_kws={'s':50})
